# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/doguy/Desktop/Planets/artifacts/PSCompPars_2023.10.03_19.49.43.csv")

# %%
df.head(5)
# Out:
#       pl_name  hostname pl_letter  sy_snum  sy_pnum  sy_mnum  discoverymethod  \
# 0    11 Com b    11 Com         b        2        1        0  Radial Velocity
# 1    11 UMi b    11 UMi         b        1        1        0  Radial Velocity
# 2    14 And b    14 And         b        1        1        0  Radial Velocity
# 3    14 Her b    14 Her         b        1        2        0  Radial Velocity
# 4  16 Cyg B b  16 Cyg B         b        3        1        0  Radial Velocity
#
#   disc_locale                           disc_facility  \
# 0      Ground                        Xinglong Station
# 1      Ground  Thueringer Landessternwarte Tautenburg
# 2      Ground       Okayama Astrophysical Observatory
# 3      Ground                  W. M. Keck Observatory
# 4      Ground                  Multiple Observatories
#
#                   disc_telescope  ... st_spectype   sy_dist  sy_disterr1  \
# 0               2.16 m Telescope  ...      G8 III   93.1846       1.9238
# ...

# %%
unique_counts = df["disc_telescope"].value_counts()
result = df[df["disc_telescope"].isin(unique_counts[unique_counts == 1].index)]

# Sonucu görüntüleyelim
result
# Out:
#                          pl_name                  hostname pl_letter  sy_snum  \
# 14     2MASS J02192210-3925225 b   2MASS J02192210-3925225         b        1
# 62                  BD+60 1417 b                BD+60 1417         b        1
# 81                  COCONUTS-2 b              COCONUTS-2 A         b        1
# 184                    GJ 1132 b                   GJ 1132         b        1
# 277                   GJ 676 A c                  GJ 676 A         c        2
# 284                     GJ 687 b                    GJ 687         b        1
# 307                      GPX-1 b                     GPX-1         b        1
# 472                  HD 102195 b                 HD 102195         b        1
# 1057                  HD 47536 b                  HD 47536         b        1
# 1171                  HD 87646 b                  HD 87646         b        3
# 1211                  HD 97048 b                  HD 97048         b        1
# ...

# %%
discovery_method = {
    'Radial Velocity': 1,
    'Imaging': 2,
    'Eclipse Timing Variations': 3,
    'Transit': 4,
    'Astrometry': 5,
    'Disk Kinematics': 6,
    'Microlensing': 7,
    'Orbital Brightness Modulation': 8,
    'Pulsation Timing Variations': 9,
    'Transit Timing Variations': 10,
    'Pulsar Timing': 11
}

disc_locale = {
    'Ground':1,
    'Space':2,
    'Multiple Locales':3
}
